# %% [markdown]
# <a href="https://colab.research.google.com/github/Marzuk1910/Smart-Traffic-Management-System/blob/main/Smart_Traffic_Light.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python-headless requests
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import requests
import time
from google.colab import files

# ===== THINGSPEAK CONFIG =====
THINGSPEAK_WRITE_KEY = "RXGGB52BACNR3Z6K"
THINGSPEAK_URL = "https://api.thingspeak.com/update"

# ===== YOLO MODEL =====
model = YOLO("yolov8n.pt")

# COCO vehicle classes
vehicle_classes = [2, 3, 5, 7]  # car, motorcycle, bus, truck

while True:
    print("Upload traffic image")
    uploaded = files.upload()
    img_path = list(uploaded.keys())[0]

    results = model(img_path)
    detections = results[0].boxes.data.cpu().numpy()

    vehicle_count = 0
    for det in detections:
        if int(det[5]) in vehicle_classes:
            vehicle_count += 1

    print("Vehicle Count:", vehicle_count)

    # Upload ONLY vehicle count
    response = requests.get(
        THINGSPEAK_URL,
        params={
            "api_key": THINGSPEAK_WRITE_KEY,
            "field1": vehicle_count,
        },
    )
    print(f"Thingspeak response: {response.status_code}")
    time.sleep(15)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Upload traffic image
#      <input type="file" id="files-4dacbd39-1c0e-4f48-878b-8455aaba48d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4dacbd39-1c0e-4f48-878b-8455aaba48d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# ...
